# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
def JonesErr(filename):
    J = np.loadtxt(filename,delimiter='\t',dtype=str)
    Targets = []
    for i in range(1,200):
        nums = ''.join(e for e in J[i,0] if e!='{' and e!="\"" and e!= "}").split(',')
        for j in range(len(nums)):
            nums[j] = float(nums[j])
        Targets.append(nums)
    # print(Targets)
    Results = []
    bads = []
    for i in range(1,200):
        nums = ''.join(e for e in J25[i,2][:J25[i,2].find(", {{")] if e!='{' and e!="\"" and e!= "}").split(',')
        for j in range(len(nums)):
            if nums[j] == " -Sign[Eigenvalues[]]":
                nums[j] = np.nan
                bads.append(i-1)
                print('row',i,'!!!',nums)
            nums[j] = float(nums[j])
        Results.append(nums)
    # print(Results)
    for i in range(len(bads)):
        del Targets[bads[i]-i]
        del Results[bads[i]-i]
    Results_npy = np.array([np.array(r) for r in Results])
    Targets_npy = np.array([np.array(t) for t in Targets])
    L2_err = np.linalg.norm(Targets_npy - Results_npy,2,0)
    ax = plt.subplot(2,2,1)
    ax.scatter(Targets_npy[:,0],Results_npy[:,0])
    ax.plot([0,25],[0,25],c='r')
    ax = plt.subplot(2,2,2)
    ax.scatter(Targets_npy[:,1],Results_npy[:,1])
    ax.plot([0,20],[0,20],c='r')
    ax = plt.subplot(2,2,3)
    ax.scatter(Targets_npy[:,2],Results_npy[:,2])
    ax.plot([-10,10],[-10,10],c='r')
    ax = plt.subplot(2,2,4)
    ax.scatter(Targets_npy[:,3],Results_npy[:,3])
    plt.show()
    return L2_err

# %%
L2_Errors = []

# %%
L2_Errors.append(JonesErr('Jones25_with_invariants.tsv'))
# Out:
# row 18 !!! [0.0, 0.0, nan, ' 1']
# row 44 !!! [0.0, 0.0, nan, ' 1']
# <img src="data:image/png;base64,..." width="640">

# %%
L2_Errors.append(JonesErr('Jones50_with_invariants.tsv'))
# Out:
# row 18 !!! [0.0, 0.0, nan, ' 1']
# row 44 !!! [0.0, 0.0, nan, ' 1']
# <img src="data:image/png;base64,..." width="640">

# %%
L2_Errors.append(JonesErr('Jones75_with_invariants.tsv'))
# Out:
# row 18 !!! [0.0, 0.0, nan, ' 1']
# row 44 !!! [0.0, 0.0, nan, ' 1']
# <img src="data:image/png;base64,..." width="640">

# %%
L2_Errors.append(JonesErr('Jones100_with_invariants.tsv'))
# Out:
# row 18 !!! [0.0, 0.0, nan, ' 1']
# row 44 !!! [0.0, 0.0, nan, ' 1']
# <img src="data:image/png;base64,..." width="640">

# %%
print(L2_Errors)
# Out:
# [array([   95.61380653,    79.79974937,    90.7964757 , 77197.01115976]), array([1.11763142e+02, 8.75899538e+01, 7.42697785e+01, 9.91092950e+04]), array([1.07531391e+02, 8.23893197e+01, 7.70194781e+01, 3.96239819e+05]), array([1.09790710e+02, 8.35703297e+01, 8.31143790e+01, 3.52903857e+05])]

# %%
JonesErr('oct19Jones_with_invariants.tsv')
# Out:
# row 18 !!! [0.0, 0.0, nan, ' 1']
# row 44 !!! [0.0, 0.0, nan, ' 1']
# <img src="data:image/png;base64,..." width="640">
# array([  120.65239326,    88.61151167,    77.33045972, 55195.57790258])
